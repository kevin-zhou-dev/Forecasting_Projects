# %% [markdown]
# # Regression models for primary election prediction in United States.
#
# ## Introduction
# The 2016 US PresIdential Election data was colllected. The dataset includes a selected set of counties in united states and their demographic information. It also includes the votes received for Hillary Clinton.
#
# Methods : Regression model to predict the percentage of votes of Hilary Clinton in primary election for each county in USA
#
# ## Table of contents
#
# ### 1-Simple Regression Model
# (5 predictors/covariates with simple variable transformation)
# -Modal
#
# -Results Analysis
#
# -Model Checking and Diagnosis
#
# -Outliers
#
# -Collinearity Diagnosis
#
# ### 2-Full Regression Model
# (multiple linear regression models with feature engineering, quadratic, interaction, or indicator variables)
#
# -Full Run
#
# -Greedy search
#
# Accuracy metrics : WMSE

# %% [markdown]
# # Importing the libraries and files

# %%
# import libraries 
import pandas as pd
pd.options.display.float_format = '{:,.0f}'.format ##or .map({:,.0f})
import numpy as np
import matplotlib.pyplot as plt 
#only in notebooks  % matplotlib inline
from matplotlib import style
style.use('ggplot')
import seaborn as sns            ##for pairplots..

import statsmodels.formula.api as smf
import statsmodels.api as sm     #for qqplots
import statsmodels.stats as sms  #for VIF

import scipy.stats as stats      #for normal distrib

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import sklearn.preprocessing as prepro
pd.options.display.max_columns=60

import util_formula ## a set of local functions and variables used 

import sklearn.preprocessing as prepro

# read the data
train = pd.read_csv('data/P1train.csv', index_col=0)
test = pd.read_csv('data/P1test.csv', index_col=0)
county_facts_dictionary = pd.read_csv('data/county_facts_dictionary.csv')
# Out:
# /home/zhou/anaconda3/lib/python3.7/site-packages/statsmodels/compat/pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %% [markdown]
# # Preprocessing

# %%
#Step 1-3 : only the first 52 columns are used 

New_index = [str(i)+' '+list(train.index)[i] for i in range(len(train.index))]
train.index=pd.Index(New_index)

train['n']=train['Bernie Sanders']+train['Hillary Clinton']
test['n']=test['Bernie Sanders']+test['Hillary Clinton']

train.drop(columns=['Bernie Sanders', 'Donald Trump', 'Hillary Clinton','John Kasich', 'Ted Cruz'],inplace=True)
train.HilaryPercent=train.HilaryPercent*100
test.drop(columns=['Bernie Sanders', 'Donald Trump', 'Hillary Clinton','John Kasich', 'Ted Cruz'],inplace=True)

#dropping rows with empty HilaryPercent
train.dropna(inplace=True)
test.dropna(inplace=True)

# %% [markdown]
# # Step 1 : Simple linear regressions

# %% [markdown]
# ## 1.1 Features

# %%
## Feature formula preparation
#Description

def GetDics(county_facts_dictionary):
    '''
    input : 
    county_facts_dictionary = columns of feature alias and feature codes
    output :
    Dic = dictionary feature codes to feature alias
    Dic_inv = dictionary feature alias to feature codes'''
    Dic,Dic_inv={},{}
    for i in range(len(county_facts_dictionary)) :
        Dic[county_facts_dictionary.values[i][0]]=county_facts_dictionary.values[i][1]
        Dic_inv[county_facts_dictionary.values[i][1]]=county_facts_dictionary.values[i][0]
    return Dic,Dic_inv

def GetDescrCodes(ListofCodes,Dic):
    '''
    input : 
    ListofCodes = list of feature alias
    Dic = Dictionary of feature alias to feature codes
    output :
    List of feature codes'''
    return [Dic[c] for c in ListofCodes]

Cols=[
"Persons 65 years and over, percent, 2014"
,"Female persons, percent, 2014"
,"Black or African American alone, percent, 2014"
,"High school graduate or higher, percent of persons age 25+, 2009-2013"
,"Persons below poverty level, percent, 2009-2013"]

##5 features taken ['AGE775214', 'SEX255214', 'RHI225214', 'EDU635213', 'PVY020213']
Features = GetDescrCodes(Cols,GetDics(county_facts_dictionary)[1])

#5 features with np.sqrt(RHI225214)
Featuressqrt=GetDescrCodes(Cols,GetDics(county_facts_dictionary)[1])
Featuressqrt[2]='np.sqrt('+Featuressqrt[2]+')' 

##Formula used in the linear regression
seperator = '+'
Formula ='HilaryPercent ~ '+seperator.join(Features)
Formulasqrt='HilaryPercent ~ '+seperator.join(Featuressqrt)

# %% [markdown]
# ## 1.2 Fitting and Evaluation of first modals

# %%
#Getwsme_OLS Performs :
#1train_test plit
#2Linear Regression on training set
#3returns wsme error metrics
#4Add pred and err to train_x_
#5Return lm,train_x_,test_x_,train_err,test_err

modal = util_formula.Getwsme_OLS('HilaryPercent',train,Formula,'1st step')[0]
modal.summary()

modalsqrt = util_formula.Getwsme_OLS('HilaryPercent',train,Formulasqrt,'1st step sqrt')[0]
modalsqrt.summary()
# Out:
# 1st step
# train error = 52.9732
# test error  = 80.0345
# 1st step sqrt
# train error = 54.6186
# test error  = 77.658
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HilaryPercent   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.600
# Method:                 Least Squares   F-statistic:                     599.6
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:10:59   Log-Likelihood:                -7424.0
# No. Observations:                1993   AIC:                         1.486e+04
# Df Residuals:                    1987   BIC:                         1.489e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             75.6881      6.057     12.496      0.000      63.810      87.567
# AGE775214              0.4936      0.055      9.014      0.000       0.386       0.601
# SEX255214              0.5660      0.102      5.568      0.000       0.367       0.765
# np.sqrt(RHI225214)     5.5994      0.131     42.649      0.000       5.342       5.857
# EDU635213             -0.7727      0.043    -17.955      0.000      -0.857      -0.688
# PVY020213             -0.3484      0.047     -7.363      0.000      -0.441      -0.256
# ==============================================================================
# Omnibus:                       68.447   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.692
# Skew:                          -0.227   Prob(JB):                     1.26e-30
# Kurtosis:                       4.205   Cond. No.                     2.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## 1.3 Diagnosis of linear regression

# %%
def diagnosisplot(lm,Features):
    '''plotting Histogram of normalized residuals
       quantile-quantile plot of the residuals
       residuals against fitted value
       partial plots'''
    #1-1Histogram of normalized residuals
    res = lm.resid
    f1 = plt.figure(figsize=(8,6))
    f1 = plt.hist(lm.resid_pearson,bins=20)
    f1 = plt.ylabel('Count')
    f1 = plt.xlabel('Normalized residuals') 

    #1-2 check the normality of the residuals
    #quantile-quantile plot of the residuals
    fig2 = plt.figure(figsize=(10,10))
    fig = sm.qqplot(lm.resid, stats.distributions.norm, line='r') 
    
    #1-3 residuals against fitted value
    fig=plt.figure(figsize=(8,6))
    ax=fig.add_subplot(111)
    ax.scatter(lm.fittedvalues,lm.resid)
    ax.axhline(y=0, linewidth=2, color = 'g')
    ax.set(xlabel='fitted values',ylabel='residuals')
    
    #2 partial plots
    for i in range(0,len(Features)):
        fig1 = plt.figure(figsize=(20,10))
        fig1 = sm.graphics.plot_regress_exog(lm, Features[i],fig=fig1)

# %%
#plots for simple modal 
sns.set(font_scale=1)
diagnosisplot(modal,Features)

# %%
#plots for simple modal with sqrt 
diagnosisplot(modalsqrt,Featuressqrt)

# %%
#clearly some colinear relationship between 2010 and April 2010
#visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, sharey=True)

train.plot(kind='scatter', y='PST045214', x='PST040210', ax=axs[0], figsize=(16, 8))
train.plot(kind='scatter', y='PST045214', x='POP010210', ax=axs[1])
train.plot(kind='scatter', y='PST040210', x='POP010210', ax=axs[2])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## 1.4 Outliers and influence points

# %%
fig, ax = plt.subplots(figsize=(14,10))
fig = sm.graphics.influence_plot(modal, ax=ax, criterion="cooks")

fig1, ax = plt.subplots(figsize=(20,10))
fig1=sm.graphics.plot_leverage_resid2(modal,ax=ax)

#low leverage influential points 
    #positive res
        #1883 NE 
        #1724 NE
        #1008 NE 
        #39 NE 
        #912 CO
    #negative res
        #1126 ID
        #1369 UT
        #2341 UT
#high leverage and high influential points 
        #469 GA
        #173 TX

## check the leverage and influential points
influence = modal.get_influence()
#c is the distance and p is p-value
(c, p) = influence.cooks_distance
fig,ax = plt.subplots(figsize=(10,6))
#ax.set
fig = plt.stem(np.arange(len(c)), c, markerfmt=",") 
plt.ylabel("Cook's distance")
plt.xlabel('index')
# Out:
# Text(0.5, 0, 'index')

# %%
def meaning(train):
    '''rename the columns'''
    return train.rename(columns=GetDics(county_facts_dictionary)[0])

### Checking some potential outilers points 
meaning(train).iloc[c.argmax()]
meaning(train).loc['1883 NE']
meaning(train).loc['1724 NE']
meaning(train).loc['1008 NE']
meaning(train).loc['39 NE']
meaning(train).loc['912 CO']

meaning(train).loc['2341 UT']
meaning(train).loc['1369 ID']
meaning(train).loc['1126 ID']

meaning(train).loc['469 GA']
meaning(train).loc['173 TX']
# Out:
# Population, 2014 estimate                                                 4,050
# Population, 2010 (April 1) estimates base                                 4,087
# Population, percent change - April 1, 2010 to July 1, 2014                   -1
# Population, 2010                                                          4,087
# Persons under 5 years, percent, 2014                                          3
# Persons under 18 years, percent, 2014                                        13
# Persons 65 years and over, percent, 2014                                     16
# Female persons, percent, 2014                                                30
# White alone, percent, 2014                                                   95
# Black or African American alone, percent, 2014                                3
# American Indian and Alaska Native alone, percent, 2014                        1
# Asian alone, percent, 2014                                                    0
# Native Hawaiian and Other Pacific Islander alone, percent, 2014               0
# Two or More Races, percent, 2014                                              1
# Hispanic or Latino, percent, 2014                                            56
# White alone, not Hispanic or Latino, percent, 2014                           41
# Living in same house 1 year & over, percent, 2009-2013                       74
# Foreign born persons, percent, 2009-2013                                     30
# Language other than English spoken at home, pct age 5+, 2009-2013            35
# High school graduate or higher, percent of persons age 25+, 2009-2013        71
# Bachelor's degree or higher, percent of persons age 25+, 2009-2013           11
# Veterans, 2009-2013                                                         267
# Mean travel time to work (minutes), workers age 16+, 2009-2013               25
# Housing units, 2014                                                       1,641
# Homeownership rate, 2009-2013                                                79
# Housing units in multi-unit structures, percent, 2009-2013                    2
# Median value of owner-occupied housing units, 2009-2013                  76,100
# Households, 2009-2013                                                       857
# Persons per household, 2009-2013                                              3
# Per capita money income in past 12 months (2013 dollars), 2009-2013      19,976
# Median household income, 2009-2013                                       51,411
# Persons below poverty level, percent, 2009-2013                              16
# Private nonfarm establishments, 2013                                         46
# Private nonfarm employment,  2013                                           734
# Private nonfarm employment, percent change, 2012-2013                         5
# Nonemployer establishments, 2013                                            218
# Total number of firms, 2007                                                 137
# Black-owned firms, percent, 2007                                              0
# American Indian- and Alaska Native-owned firms, percent, 2007                 0
# Asian-owned firms, percent, 2007                                              0
# Native Hawaiian- and Other Pacific Islander-owned firms, percent, 2007        0
# Hispanic-owned firms, percent, 2007                                           0
# Women-owned firms, percent, 2007                                              0
# Manufacturers shipments, 2007 ($1,000)                                        0
# Merchant wholesaler sales, 2007 ($1,000)                                      0
# Retail sales, 2007 ($1,000)                                              17,668
# Retail sales per capita, 2007                                             4,930
# Accommodation and food services sales, 2007 ($1,000)                      4,346
# Building permits, 2014                                                        0
# Land area in square miles, 2010                                             984
# Population per square mile, 2010                                              4
# HilaryPercent                                                                71
# n                                                                            38
# Name: 173 TX, dtype: float64

# %% [markdown]
# ## 1.5 Collinearity

# %%
# pair plot of some variables of interest
sns.set(font_scale=1)
b=sns.pairplot(data=train[Features],diag_kind='kde',height=2, 
aspect=2, #Size of 1 plot, width = height* aspect
kind='reg')

#Variance inflation factor
for i in range(6):
     print('VIF for '+modal.model.exog_names[i]+':'+str( sms.outliers_influence.variance_inflation_factor(modal.model.exog, i)))
# Out:
# VIF for Intercept:726.2140600438565
# VIF for AGE775214:1.0588089877517963
# VIF for SEX255214:1.0438512932248947
# VIF for RHI225214:1.3246224792206664
# VIF for EDU635213:1.7598014856869153
# VIF for PVY020213:1.9340751008710124

# %% [markdown]
# # Step 2 : Multiple linear regression

# %%
# load the functions to be used
from util_formula import *

y = 'HilaryPercent'

Cols=[
"Persons 65 years and over, percent, 2014"
,"Female persons, percent, 2014" 
,"Black or African American alone, percent, 2014"
,"High school graduate or higher, percent of persons age 25+, 2009-2013"
,"Persons below poverty level, percent, 2009-2013"]

Features=[ 'Q("'+ x +'")' for x in Cols]
Features[2]='np.sqrt('+Features[2]+')' #np.sqrt(Q("Black or African American alone, percent, 2014"))

seperator = '+'
Features_concat=seperator.join(Features)

# %%
Candidates =['PST045214', 'PST120214', 'AGE135214', 'AGE295214', 'AGE775214', 'SEX255214', 'RHI125214', 'RHI225214', 'RHI325214', 'RHI425214', 'RHI525214', 'RHI625214', 'RHI725214', 'RHI825214', 'POP715213', 'POP645213', 'POP815213', 'EDU635213', 'EDU685213', 'VET605213', 'LFE305213', 'HSG010214',
       'HSG445213', 'HSG096213', 'HSG495213', 'HSD410213', 'HSD310213', 'INC910213', 'INC110213', 'PVY020213', 'BZA010213', 'BZA110213', 'BZA115213', 'NES010213', 'SBO001207', 'SBO315207', 'SBO115207', 'SBO215207', 'SBO515207', 'SBO415207', 'SBO015207', 'MAN450207', 'WTN220207', 'RTN130207', 'RTN131207', 'AFN120207',
       'BPS030214', 'LND110210', 'POP060210']
## does not include n (number of democratic voter), 'HilaryPercent', 'Population, 2010 (April 1) estimates base','Population, 2010',

# %% [markdown]
# ## 2.1 Step 1 : Full run with 5 variables

# %%
#ols modal
fullmodel = modelFitting(y, Candidates, train)
# enumerate all models and obtain the results
models = pd.DataFrame({"model":[], "SSE": [], "R2":[], "AR2": [], "AIC": [], "BIC": [], "Pnum":[]})
## process all modals from 3 to 5 variables : 
'''for i in range(3,5):
    models = models.append(getAll(i, y, Candidates, train));
    
# get the Mallow's Cp Statistic
models = getMallowCp(models, fullmodel)

findBest(models, 'R2')'''

#returns the following features (running again the function take a lot of time)
Features=['AGE775214','SEX255214','RHI225214','EDU635213','PVY020213']
model = modelFitting(y, Features, train)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HilaryPercent   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     699.9
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:11:50   Log-Likelihood:                -9343.5
# No. Observations:                2492   AIC:                         1.870e+04
# Df Residuals:                    2486   BIC:                         1.873e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     94.6485      5.628     16.818      0.000      83.613     105.684
# AGE775214      0.3578      0.049      7.342      0.000       0.262       0.453
# SEX255214      0.5128      0.096      5.359      0.000       0.325       0.700
# RHI225214      0.7375      0.016     46.125      0.000       0.706       0.769
# EDU635213     -0.8377      0.040    -20.915      0.000      -0.916      -0.759
# PVY020213     -0.4800      0.044    -10.860      0.000      -0.567      -0.393
# ==============================================================================
# Omnibus:                      114.608   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              255.749
# Skew:                          -0.285   Prob(JB):                     2.92e-56
# Kurtosis:                       4.463   Cond. No.                     2.77e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.77e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## 2.2 Step 2 Forward selection

# %%
# use forward selection to get the best model
'''fwmodel = forward(y, Candidates, train, 'AIC')'''

#returns the following features (running again the function take a lot of time)
Features_fw=['RHI225214', 'EDU635213', 'RHI625214', 'INC910213', 'HSG495213', 'SBO415207', 'EDU685213', 'AGE775214', 'PST120214', 'RHI825214', 'LND110210', 'SEX255214', 'SBO315207', 'RHI425214', 'POP645213', 'AGE135214', 'HSD310213', 'POP715213', 'RHI325214', 'LFE305213', 'RHI725214', 'HSG445213', 'HSG096213', 'POP060210']
model = modelFitting(y, Features_fw, train)
model.summary()

#AIC:                         1.760e+04
#R-squared:                       0.662
#Adj. R-squared:                  0.659
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HilaryPercent   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     198.2
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:13:09   Log-Likelihood:                -9099.5
# No. Observations:                2492   AIC:                         1.825e+04
# Df Residuals:                    2467   BIC:                         1.839e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    137.0476     32.319      4.240      0.000      73.673     200.423
# RHI225214     -0.0777      0.312     -0.249      0.803      -0.690       0.535
# EDU635213     -0.4348      0.053     -8.259      0.000      -0.538      -0.332
# RHI625214     -2.7362      0.355     -7.700      0.000      -3.433      -2.039
# INC910213      0.0011   8.27e-05     13.481      0.000       0.001       0.001
# HSG495213  -3.954e-05   5.25e-06     -7.536      0.000   -4.98e-05   -2.93e-05
# SBO415207      0.0832      0.044      1.910      0.056      -0.002       0.169
# EDU685213     -0.3971      0.051     -7.752      0.000      -0.497      -0.297
# AGE775214      0.5621      0.081      6.913      0.000       0.403       0.722
# PST120214      0.4563      0.066      6.887      0.000       0.326       0.586
# RHI825214     -0.9001      0.316     -2.852      0.004      -1.519      -0.281
# LND110210     -0.0005      0.000     -3.050      0.002      -0.001      -0.000
# SEX255214      0.4961      0.104      4.774      0.000       0.292       0.700
# SBO315207     -0.1458      0.038     -3.800      0.000      -0.221      -0.071
# RHI425214     -0.0140      0.356     -0.039      0.969      -0.712       0.684
# POP645213     -0.3584      0.080     -4.468      0.000      -0.516      -0.201
# AGE135214     -0.7664      0.280     -2.737      0.006      -1.315      -0.217
# HSD310213      6.2868      1.514      4.152      0.000       3.318       9.256
# POP715213     -0.1554      0.063     -2.462      0.014      -0.279      -0.032
# RHI325214     -0.7809      0.302     -2.582      0.010      -1.374      -0.188
# LFE305213      0.0730      0.051      1.431      0.153      -0.027       0.173
# RHI725214     -0.6611      0.301     -2.196      0.028      -1.251      -0.071
# HSG445213     -0.0996      0.048     -2.065      0.039      -0.194      -0.005
# HSG096213     -0.0840      0.045     -1.862      0.063      -0.172       0.004
# POP060210      0.0002      0.000      1.573      0.116   -5.11e-05       0.000
# ==============================================================================
# Omnibus:                      111.204   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              297.538
# Skew:                          -0.201   Prob(JB):                     2.46e-65
# Kurtosis:                       4.644   Cond. No.                     2.62e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.62e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## 2.3 Step 2 Backward selection

# %%
'''bwmodel = backward(y, Candidates, train, 'AIC')
bwmodel.summary()'''

#returns the following features (running again the function take a lot of time)
Features_bw=['PST045214', 'AGE295214', 'RHI325214', 'RHI525214', 'POP815213', 'HSG010214', 'INC110213', 'PVY020213', 'BZA110213', 'BZA115213', 'NES010213', 'SBO115207', 'SBO215207', 'SBO015207', 'MAN450207', 'WTN220207', 'RTN131207', 'AFN120207', 'BPS030214']
model = modelFitting(y, Features_bw, train)
model.summary()

#AIC:                         1.757e+04
#R-squared:                       0.668
#Adj. R-squared:                  0.664
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HilaryPercent   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     34.23
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):          1.17e-110
# Time:                        16:13:11   Log-Likelihood:                -10147.
# No. Observations:                2492   AIC:                         2.033e+04
# Df Residuals:                    2472   BIC:                         2.045e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     25.6601      3.511      7.309      0.000      18.776      32.544
# PST045214  -4.026e-05   1.14e-05     -3.520      0.000   -6.27e-05   -1.78e-05
# AGE295214      0.5458      0.100      5.460      0.000       0.350       0.742
# RHI325214     -0.6815      0.063    -10.740      0.000      -0.806      -0.557
# RHI525214     -6.4629      0.866     -7.460      0.000      -8.162      -4.764
# POP815213      0.0158      0.029      0.548      0.584      -0.041       0.072
# HSG010214   4.943e-05   2.56e-05      1.929      0.054   -8.19e-07    9.97e-05
# INC110213   4.521e-05   4.72e-05      0.958      0.338   -4.73e-05       0.000
# PVY020213      1.0207      0.079     12.935      0.000       0.866       1.175
# BZA110213  -1.268e-05    1.2e-05     -1.060      0.289   -3.61e-05    1.08e-05
# BZA115213      0.1073      0.048      2.240      0.025       0.013       0.201
# NES010213      0.0003   7.57e-05      3.318      0.001       0.000       0.000
# SBO115207      0.2300      0.150      1.532      0.126      -0.064       0.524
# SBO215207      0.9906      0.194      5.119      0.000       0.611       1.370
# SBO015207      0.0755      0.025      3.040      0.002       0.027       0.124
# MAN450207     9.4e-08   1.18e-07      0.794      0.427   -1.38e-07    3.26e-07
# WTN220207   3.907e-08   1.23e-07      0.316      0.752   -2.03e-07    2.81e-07
# RTN131207     -0.0002   5.78e-05     -4.200      0.000      -0.000      -0.000
# AFN120207   3.724e-07   6.67e-07      0.558      0.577   -9.36e-07    1.68e-06
# BPS030214   3.572e-05      0.000      0.089      0.929      -0.001       0.001
# ==============================================================================
# Omnibus:                       17.279   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.010
# Skew:                          -0.155   Prob(JB):                     7.45e-05
# Kurtosis:                       3.295   Cond. No.                     1.17e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## 2.4 Step 2 Inclusion of  interactions in the predictors

# %%
'''cand_2Inter = []
for p1 in Candidates:
    for p2 in Candidates:
        if p1 == p2:
            cand_2Inter.append(p1);
        else:
            cand_2Inter.append(p1+':'+p2);
                
print(cand_2Inter)
print(len(cand_2Inter))

# forward selection with interaction considered
fwmodel = forward(y, cand_2Inter, train, 'AIC')'''
#returns
Features_fw_int=['RHI125214:RHI225214', 'RHI625214:RHI825214', 'RHI825214:HSG096213', 'AGE775214:HSG096213', 'EDU635213', 'SEX255214:INC910213', 'POP715213:HSG495213', 'RHI225214:HSD410213', 'HSG495213:INC110213', 'RHI825214:POP645213', 'RHI725214:LFE305213', 'AGE295214:AGE775214', 'RHI225214:HSD310213', 'SEX255214:RHI225214', 'PST120214:PVY020213', 'AGE135214:INC110213', 'AGE775214:EDU685213', 'RHI125214:RHI425214', 'AGE295214:HSG495213', 'PST120214:RHI825214', 'POP715213:INC910213', 'EDU635213:HSG495213', 'RHI525214:POP060210', 'AGE295214:INC910213', 'SEX255214:HSG495213', 'RHI525214:SBO315207', 'SBO115207:LND110210', 'RHI325214:POP645213', 'AGE135214:HSG445213', 'RHI325214:HSG495213', 'RHI125214:INC910213', 'RHI725214:POP815213', 'AGE295214:POP815213', 'AGE135214:RHI425214', 'AGE775214:BZA115213', 'AGE135214:POP815213', 'INC910213:PVY020213', 'POP815213:HSD310213', 'RHI425214:POP645213', 'PST120214:RHI625214', 'RHI325214:VET605213', 'HSG445213:PVY020213', 'INC910213:INC110213', 'HSG495213:PVY020213', 'AGE295214:RHI225214', 'RHI225214:HSG445213', 'RHI225214:EDU685213', 'PVY020213:SBO515207', 'POP815213:LND110210', 'SBO315207:SBO015207', 'AGE135214:AGE775214', 'RHI725214:HSG495213', 'POP815213:INC110213', 'RHI225214:POP815213', 'HSG096213:SBO315207', 'RHI225214:RHI825214', 'HSG445213:BZA110213', 'RHI225214:NES010213', 'POP645213:SBO315207', 'AGE775214:RHI625214', 'AGE775214:VET605213', 'BZA115213:LND110210', 'HSG445213:WTN220207', 'AGE295214:HSG445213', 'HSG096213:LND110210', 'AGE135214:LND110210', 'LFE305213:LND110210', 'PST120214:HSG495213', 'PST120214:AGE295214', 'PST120214:EDU635213', 'PST120214:HSG445213', 'AGE775214:POP645213', 'EDU685213:INC110213', 'AGE775214:INC110213', 'RHI425214:SBO415207', 'EDU635213:INC910213', 'SEX255214', 'SEX255214:EDU635213', 'MAN450207:RTN130207', 'RHI625214:SBO315207', 'RHI825214', 'RHI225214:SBO001207', 'RHI525214:VET605213', 'RHI525214:RHI725214', 'RHI825214:SBO415207', 'HSG495213:SBO415207', 'RHI525214:POP815213', 'PST120214:AGE775214', 'PST120214:HSD310213', 'AGE775214:RHI225214', 'HSG010214:HSG445213', 'RHI525214:HSG010214', 'AGE135214:EDU635213', 'PST045214:RHI225214', 'RHI325214:HSD310213', 'SEX255214:RHI725214', 'PST120214:INC910213', 'AGE775214:HSG495213', 'AGE775214:PVY020213', 'RHI325214:PVY020213', 'SEX255214:EDU685213', 'EDU685213:PVY020213', 'POP645213:SBO115207', 'BZA115213', 'LFE305213:HSD310213', 'RHI225214:RHI625214', 'AGE775214:EDU635213', 'PST120214:INC110213', 'AGE135214:RHI225214', 'POP815213:HSG495213', 'RHI825214:NES010213', 'RHI425214:BZA115213', 'INC910213:BZA115213', 'EDU635213:EDU685213', 'AGE295214:BZA010213', 'POP815213:RTN130207', 'AGE295214:RHI625214', 'AGE775214:HSG445213', 'PST120214:AGE135214', 'RHI725214:SBO315207', 'EDU685213:AFN120207', 'POP815213:SBO315207', 'HSG445213:HSG495213', 'RHI625214:PVY020213', 'HSD410213:SBO015207', 'EDU685213:HSD310213', 'RHI325214:SBO215207', 'POP645213:SBO215207', 'SBO015207', 'POP715213:HSG010214', 'EDU685213:SBO015207', 'SBO115207:SBO415207', 'HSG096213:SBO015207', 'SBO315207:AFN120207', 'RHI225214:RHI725214', 'POP645213:HSG495213', 'RHI125214:HSG495213', 'AGE135214:NES010213', 'SBO315207:SBO215207', 'PST120214:POP060210', 'SBO315207:SBO415207', 'POP645213:INC910213', 'AGE135214:SBO315207', 'POP645213:RTN131207', 'RHI625214:LFE305213', 'POP715213:RTN131207']
model = modelFitting(y, Features_fw_int, train)
model.summary()
#R-squared:                       0.768
#Adj. R-squared:                  0.758
#AIC:                         1.685e+04
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HilaryPercent   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     76.32
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:13:44   Log-Likelihood:                -8662.5
# No. Observations:                2492   AIC:                         1.753e+04
# Df Residuals:                    2392   BIC:                         1.811e+04
# Df Model:                          99
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0031      0.001     -4.726      0.000      -0.004      -0.002
# RHI125214:RHI225214     0.0425      0.024      1.784      0.075      -0.004       0.089
# RHI625214:RHI825214     0.0002      0.014      0.013      0.989      -0.027       0.028
# RHI825214:HSG096213    -0.0009      0.002     -0.526      0.599      -0.004       0.002
# AGE775214:HSG096213     0.0087      0.007      1.205      0.228      -0.005       0.023
# EDU635213              -0.2340      0.250     -0.935      0.350      -0.725       0.257
# SEX255214:INC910213 -2.501e-05   2.21e-05     -1.133      0.257   -6.83e-05    1.83e-05
# POP715213:HSG495213  1.671e-06   9.22e-07      1.813      0.070   -1.36e-07    3.48e-06
# RHI225214:HSD410213 -5.191e-06   2.76e-06     -1.882      0.060   -1.06e-05    2.18e-07
# HSG495213:INC110213  4.185e-09   6.49e-10      6.448      0.000    2.91e-09    5.46e-09
# RHI825214:POP645213    -0.0045      0.004     -1.252      0.211      -0.012       0.003
# RHI725214:LFE305213     0.0061      0.003      1.821      0.069      -0.000       0.013
# AGE295214:AGE775214    -0.0599      0.026     -2.312      0.021      -0.111      -0.009
# RHI225214:HSD310213     0.0729      0.077      0.949      0.343      -0.078       0.224
# SEX255214:RHI225214    -0.0140      0.006     -2.245      0.025      -0.026      -0.002
# PST120214:PVY020213    -0.0027      0.016     -0.167      0.867      -0.034       0.029
# AGE135214:INC110213 -2.733e-06   1.95e-05     -0.140      0.888   -4.09e-05    3.55e-05
# AGE775214:EDU685213     0.0141      0.011      1.275      0.202      -0.008       0.036
# RHI125214:RHI425214    -0.0030      0.007     -0.437      0.662      -0.017       0.011
# AGE295214:HSG495213 -1.319e-05   1.57e-06     -8.399      0.000   -1.63e-05   -1.01e-05
# PST120214:RHI825214     0.0148      0.004      3.308      0.001       0.006       0.024
# POP715213:INC910213 -1.393e-05   5.64e-06     -2.469      0.014    -2.5e-05   -2.87e-06
# EDU635213:HSG495213 -5.503e-06   9.43e-07     -5.837      0.000   -7.35e-06   -3.65e-06
# RHI525214:POP060210    -0.0013      0.001     -0.865      0.387      -0.004       0.002
# AGE295214:INC910213     0.0001    1.8e-05      5.658      0.000    6.67e-05       0.000
# SEX255214:HSG495213  1.154e-05   2.11e-06      5.463      0.000     7.4e-06    1.57e-05
# RHI525214:SBO315207     0.2986      0.275      1.084      0.278      -0.241       0.839
# SBO115207:LND110210  3.263e-05   3.62e-05      0.900      0.368   -3.84e-05       0.000
# RHI325214:POP645213    -0.1133      0.025     -4.593      0.000      -0.162      -0.065
# AGE135214:HSG445213    -0.1555      0.029     -5.409      0.000      -0.212      -0.099
# RHI325214:HSG495213  2.567e-06   1.03e-06      2.501      0.012    5.54e-07    4.58e-06
# RHI125214:INC910213  7.717e-06   5.51e-06      1.401      0.161   -3.08e-06    1.85e-05
# RHI725214:POP815213     0.0025      0.002      1.600      0.110      -0.001       0.005
# AGE295214:POP815213    -0.0332      0.012     -2.772      0.006      -0.057      -0.010
# AGE135214:RHI425214     0.2014      0.096      2.087      0.037       0.012       0.391
# AGE775214:BZA115213     0.0258      0.008      3.243      0.001       0.010       0.041
# AGE135214:POP815213     0.0658      0.033      2.014      0.044       0.002       0.130
# INC910213:PVY020213 -7.014e-05   1.47e-05     -4.782      0.000   -9.89e-05   -4.14e-05
# POP815213:HSD310213     0.0185      0.067      0.274      0.784      -0.114       0.151
# RHI425214:POP645213    -0.0506      0.021     -2.411      0.016      -0.092      -0.009
# PST120214:RHI625214    -0.0727      0.061     -1.192      0.233      -0.192       0.047
# RHI325214:VET605213  4.979e-05   1.45e-05      3.440      0.001    2.14e-05    7.82e-05
# HSG445213:PVY020213     0.0066      0.003      1.990      0.047    9.51e-05       0.013
# INC910213:INC110213 -5.757e-08   8.24e-09     -6.984      0.000   -7.37e-08   -4.14e-08
# HSG495213:PVY020213  2.864e-06   1.37e-06      2.086      0.037    1.72e-07    5.56e-06
# AGE295214:RHI225214     0.0014      0.010      0.145      0.884      -0.018       0.021
# RHI225214:HSG445213     0.0114      0.002      5.032      0.000       0.007       0.016
# RHI225214:EDU685213     0.0129      0.003      3.779      0.000       0.006       0.020
# PVY020213:SBO515207     0.0158      0.153      0.103      0.918      -0.284       0.316
# POP815213:LND110210 -1.906e-05   1.29e-05     -1.472      0.141   -4.44e-05    6.33e-06
# SBO315207:SBO015207    -0.0046      0.002     -1.980      0.048      -0.009   -4.46e-05
# AGE135214:AGE775214     0.3405      0.085      4.013      0.000       0.174       0.507
# RHI725214:HSG495213  1.922e-07    6.6e-07      0.291      0.771    -1.1e-06    1.49e-06
# POP815213:INC110213  1.135e-05   3.17e-06      3.582      0.000    5.13e-06    1.76e-05
# RHI225214:POP815213    -0.0216      0.007     -2.993      0.003      -0.036      -0.007
# HSG096213:SBO315207     0.0078      0.005      1.603      0.109      -0.002       0.017
# RHI225214:RHI825214    -0.0300      0.024     -1.243      0.214      -0.077       0.017
# HSG445213:BZA110213  5.756e-07   2.66e-07      2.165      0.030    5.43e-08     1.1e-06
# RHI225214:NES010213 -2.176e-06   9.96e-06     -0.218      0.827   -2.17e-05    1.74e-05
# POP645213:SBO315207    -0.0185      0.024     -0.789      0.430      -0.065       0.028
# AGE775214:RHI625214    -0.1229      0.053     -2.316      0.021      -0.227      -0.019
# AGE775214:VET605213  1.236e-05   4.12e-06      2.996      0.003    4.27e-06    2.04e-05
# BZA115213:LND110210 -4.578e-05   3.08e-05     -1.487      0.137      -0.000    1.46e-05
# HSG445213:WTN220207  3.805e-09   1.28e-09      2.971      0.003    1.29e-09    6.32e-09
# AGE295214:HSG445213     0.0224      0.007      3.009      0.003       0.008       0.037
# HSG096213:LND110210    4.9e-05   2.28e-05      2.147      0.032    4.25e-06    9.37e-05
# AGE135214:LND110210    -0.0001   9.04e-05     -1.212      0.226      -0.000    6.77e-05
# LFE305213:LND110210  1.923e-05   2.11e-05      0.910      0.363   -2.22e-05    6.07e-05
# PST120214:HSG495213 -8.691e-07   1.41e-06     -0.618      0.537   -3.63e-06    1.89e-06
# PST120214:AGE295214     0.0013      0.031      0.042      0.967      -0.059       0.062
# PST120214:EDU635213    -0.0373      0.010     -3.746      0.000      -0.057      -0.018
# PST120214:HSG445213     0.0426      0.009      4.663      0.000       0.025       0.061
# AGE775214:POP645213     0.0096      0.012      0.777      0.437      -0.015       0.034
# EDU685213:INC110213  2.048e-05   5.47e-06      3.741      0.000    9.74e-06    3.12e-05
# AGE775214:INC110213  1.912e-05   7.52e-06      2.543      0.011    4.38e-06    3.39e-05
# RHI425214:SBO415207     0.0338      0.024      1.385      0.166      -0.014       0.082
# EDU635213:INC910213  4.365e-05   1.18e-05      3.684      0.000    2.04e-05    6.69e-05
# SEX255214               1.4939      0.309      4.831      0.000       0.888       2.100
# SEX255214:EDU635213    -0.0069      0.004     -1.894      0.058      -0.014       0.000
# MAN450207:RTN130207 -5.529e-15   1.85e-15     -2.988      0.003   -9.16e-15    -1.9e-15
# RHI625214:SBO315207     0.0551      0.065      0.852      0.395      -0.072       0.182
# RHI825214               0.0146      0.150      0.097      0.923      -0.279       0.308
# RHI225214:SBO001207 -7.515e-07   8.98e-06     -0.084      0.933   -1.84e-05    1.69e-05
# RHI525214:VET605213    -0.0003      0.000     -2.490      0.013      -0.001   -6.27e-05
# RHI525214:RHI725214    -0.0092      0.123     -0.075      0.941      -0.250       0.232
# RHI825214:SBO415207    -0.0074      0.002     -3.361      0.001      -0.012      -0.003
# HSG495213:SBO415207  1.895e-06   8.21e-07      2.308      0.021    2.85e-07     3.5e-06
# RHI525214:POP815213     0.1932      0.111      1.734      0.083      -0.025       0.412
# PST120214:AGE775214    -0.0479      0.015     -3.236      0.001      -0.077      -0.019
# PST120214:HSD310213    -0.0095      0.293     -0.032      0.974      -0.584       0.565
# AGE775214:RHI225214    -0.0210      0.007     -3.132      0.002      -0.034      -0.008
# HSG010214:HSG445213 -2.072e-06   4.62e-07     -4.488      0.000   -2.98e-06   -1.17e-06
# RHI525214:HSG010214  4.124e-05   2.21e-05      1.870      0.062   -2.01e-06    8.45e-05
# AGE135214:EDU635213     0.0347      0.015      2.263      0.024       0.005       0.065
# PST045214:RHI225214  2.109e-06   1.04e-06      2.032      0.042    7.37e-08    4.14e-06
# RHI325214:HSD310213     0.1653      0.082      2.010      0.045       0.004       0.327
# SEX255214:RHI725214    -0.0008      0.003     -0.234      0.815      -0.007       0.006
# PST120214:INC910213  7.926e-05   2.27e-05      3.485      0.001    3.47e-05       0.000
# AGE775214:HSG495213 -3.779e-06   1.33e-06     -2.840      0.005   -6.39e-06   -1.17e-06
# AGE775214:PVY020213     0.0150      0.013      1.175      0.240      -0.010       0.040
# RHI325214:PVY020213    -0.0131      0.006     -2.104      0.036      -0.025      -0.001
# SEX255214:EDU685213    -0.0595      0.014     -4.344      0.000      -0.086      -0.033
# EDU685213:PVY020213     0.0151      0.009      1.608      0.108      -0.003       0.034
# POP645213:SBO115207     0.0921      0.041      2.272      0.023       0.013       0.172
# BZA115213              -0.1507      0.196     -0.770      0.441      -0.535       0.233
# LFE305213:HSD310213    -0.0072      0.033     -0.220      0.826      -0.071       0.057
# RHI225214:RHI625214    -0.0433      0.034     -1.261      0.208      -0.111       0.024
# AGE775214:EDU635213    -0.0214      0.008     -2.835      0.005      -0.036      -0.007
# PST120214:INC110213 -3.864e-05   1.34e-05     -2.878      0.004    -6.5e-05   -1.23e-05
# AGE135214:RHI225214     0.0393      0.022      1.809      0.071      -0.003       0.082
# POP815213:HSG495213 -1.346e-06   1.06e-06     -1.268      0.205   -3.43e-06    7.35e-07
# RHI825214:NES010213  6.167e-06    1.6e-06      3.860      0.000    3.03e-06     9.3e-06
# RHI425214:BZA115213     0.0712      0.035      2.060      0.039       0.003       0.139
# INC910213:BZA115213 -1.184e-05   6.78e-06     -1.747      0.081   -2.51e-05    1.45e-06
# EDU635213:EDU685213     0.0099      0.006      1.586      0.113      -0.002       0.022
# AGE295214:BZA010213 -8.714e-05   1.97e-05     -4.414      0.000      -0.000   -4.84e-05
# POP815213:RTN130207  1.732e-08      1e-08      1.725      0.085   -2.36e-09     3.7e-08
# AGE295214:RHI625214    -0.1129      0.046     -2.473      0.013      -0.202      -0.023
# AGE775214:HSG445213     0.0180      0.005      3.600      0.000       0.008       0.028
# PST120214:AGE135214     0.0674      0.084      0.803      0.422      -0.097       0.232
# RHI725214:SBO315207    -0.0360      0.019     -1.912      0.056      -0.073       0.001
# EDU685213:AFN120207 -6.236e-08   3.46e-08     -1.804      0.071    -1.3e-07    5.44e-09
# POP815213:SBO315207     0.0124      0.022      0.554      0.580      -0.031       0.056
# HSG445213:HSG495213 -1.478e-06   5.65e-07     -2.615      0.009   -2.59e-06    -3.7e-07
# RHI625214:PVY020213     0.0817      0.036      2.272      0.023       0.011       0.152
# HSD410213:SBO015207 -1.014e-06    7.3e-07     -1.389      0.165   -2.45e-06    4.18e-07
# EDU685213:HSD310213     0.1701      0.085      2.011      0.044       0.004       0.336
# RHI325214:SBO215207    -0.0778      0.083     -0.935      0.350      -0.241       0.085
# POP645213:SBO215207     0.0265      0.017      1.589      0.112      -0.006       0.059
# SBO015207               0.1178      0.043      2.737      0.006       0.033       0.202
# POP715213:HSG010214  9.953e-07   4.84e-07      2.056      0.040    4.62e-08    1.94e-06
# EDU685213:SBO015207    -0.0037      0.003     -1.451      0.147      -0.009       0.001
# SBO115207:SBO415207    -0.0171      0.017     -0.992      0.321      -0.051       0.017
# HSG096213:SBO015207    -0.0042      0.003     -1.587      0.113      -0.009       0.001
# SBO315207:AFN120207  1.494e-07   1.25e-07      1.193      0.233   -9.62e-08    3.95e-07
# RHI225214:RHI725214    -0.0059      0.022     -0.272      0.786      -0.048       0.036
# POP645213:HSG495213 -3.948e-06   1.47e-06     -2.678      0.007   -6.84e-06   -1.06e-06
# RHI125214:HSG495213 -5.423e-07   5.12e-07     -1.060      0.289   -1.55e-06    4.61e-07
# AGE135214:NES010213  3.666e-05   1.54e-05      2.379      0.017    6.44e-06    6.69e-05
# SBO315207:SBO215207    -0.0197      0.017     -1.124      0.261      -0.054       0.015
# PST120214:POP060210    -0.0002   9.03e-05     -1.899      0.058      -0.000    5.59e-06
# SBO315207:SBO415207     0.0208      0.019      1.096      0.273      -0.016       0.058
# POP645213:INC910213   1.54e-05   1.29e-05      1.198      0.231   -9.81e-06    4.06e-05
# AGE135214:SBO315207     0.0043      0.019      0.226      0.822      -0.033       0.042
# POP645213:RTN131207  1.647e-05   8.24e-06      2.000      0.046    3.21e-07    3.26e-05
# RHI625214:LFE305213     0.0421      0.036      1.186      0.236      -0.028       0.112
# POP715213:RTN131207 -4.424e-07   5.92e-07     -0.747      0.455    -1.6e-06    7.18e-07
# ==============================================================================
# Omnibus:                      110.232   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              341.026
# Skew:                          -0.111   Prob(JB):                     8.85e-75
# Kurtosis:                       4.799   Cond. No.                     2.56e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
nfold = 10
kf = KFold(nfold, shuffle=True)

ListFeatures=[Features,Featuressqrt,Candidates,Features_fw,Features_bw,Features_fw_int]
ListFormula = ['HilaryPercent ~ '+seperator.join(i) for i in ListFeatures]

Name = ['1st step with 5 features','1st step with 5 features and sqrt for RHI225214','all features','Features with fw','Features with bw','Features and second order int with fw']
modals= []

for i in range(0,len(ListFeatures)):
    Function1 = util_formula.Getwsme_OLS('HilaryPercent',train,ListFormula[i],Name[i])
    modals.append(Function1[0])
    #train_x_=Function1[1]
    print('rsquare: {}'.format(modals[i].rsquared))
    cverr= util_formula.CrossValidation('HilaryPercent',ListFeatures[i], train, kf.split(train))
    print('mean error using cross validation: {}'.format(np.mean(cverr)))
    print('\n')
# Out:
# 1st step with 5 features
# train error = 52.9732
# test error  = 80.0345
# rsquare: 0.5781627658600963
# /home/zhou/Documents/Projects_NUS_Applied Forecasting Methods/util_formula.py:292: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   d_train, d_test = data.ix[train_index,], data.ix[test_index,]
# mean error using cross validation: 57.726521903866114
#
#
# 1st step with 5 features and sqrt for RHI225214
# train error = 54.6186
# test error  = 77.658
# rsquare: 0.6014024975364157
# mean error using cross validation: 59.112577587107936
#
#
# all features
# train error = 35.4676
# test error  = 65.9824
# rsquare: 0.6605397678200681
# mean error using cross validation: 57.204088301778995
#
#
# Features with fw
# train error = 37.1801
# test error  = 79.7781
# rsquare: 0.6531166054423876
# mean error using cross validation: 46.60741757219044
#
#
# Features with bw
# train error = 115.4165
# test error  = 114.8296
# rsquare: 0.22077800984121798
# mean error using cross validation: 146.13472592083082
#
#
# Features and second order int with fw
# train error = 26.0494
# test error  = 61.4333
# rsquare: 0.7581795549498849
# mean error using cross validation: 60.99210687696726

# %% [markdown]
# ## 2.5 Step 2 Weighted linear regression

# %%
def CrossValidation_WLS(y, X, data, kf,weights,hasconst=False):
    """
The function compute the cross validation results 
X: is the list of all predictors to be included
y: is the dependent variable to be predicted (in string)
data: is the dataframe of all data
kf: is the kfold.split() generated by the function from sklearn
'n' column : nber of democratic votes
@return: the cross validated MSE 
"""
    results = []

    # evaluate all accuracy based on the folds
    for train_index, test_index in kf:
        d_train, d_test = data.ix[train_index,], data.ix[test_index,]

        # fit the model and evaluate the prediction
        lmfit= sm.WLS(d_train[y],
                      d_train[X],
                      weights=d_train[weights],
                      hasconst=hasconst).fit()
        prederror = wsme(d_test[y],lmfit.predict(d_test[X]),d_test['n'])
        results.append(prederror);
        
    # Wrap everything up in a nice dataframe
    return results;

# %%
### We will consider the features using the foward selection

## Cross valdiation with OLS
np.mean(util_formula.CrossValidation('HilaryPercent',Features_fw, train, kf.split(train)))
# Out:
# 52.33187061823778

# %%
## Cross validation with WLS 
np.mean(CrossValidation_WLS('HilaryPercent', Features_fw, train[Features_fw+['HilaryPercent','PST045214','n']],  kf.split(train),weights='PST045214'))
# Out:
# /home/zhou/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   from ipykernel import kernelapp as app
# 39.7645401278173

# %%
##modal fitting with weights= nber of democratic voters 
y='HilaryPercent'
weights='n'
X=Features_fw
lmfit2= sm.WLS(train[y],train[X],weights=train[weights]).fit()

lmfit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  WLS Regression Results
# =======================================================================================
# Dep. Variable:          HilaryPercent   R-squared (uncentered):                   0.991
# Model:                            WLS   Adj. R-squared (uncentered):              0.991
# Method:                 Least Squares   F-statistic:                          1.163e+04
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):                        0.00
# Time:                        16:14:07   Log-Likelihood:                         -9920.4
# No. Observations:                2492   AIC:                                  1.989e+04
# Df Residuals:                    2468   BIC:                                  2.003e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RHI225214      1.0946      0.066     16.526      0.000       0.965       1.225
# EDU635213     -0.3147      0.051     -6.227      0.000      -0.414      -0.216
# RHI625214     -1.2678      0.137     -9.229      0.000      -1.537      -0.998
# INC910213      0.0012   4.79e-05     25.615      0.000       0.001       0.001
# HSG495213   -9.67e-06    2.6e-06     -3.723      0.000   -1.48e-05   -4.58e-06
# SBO415207      0.3274      0.035      9.372      0.000       0.259       0.396
# EDU685213     -0.5736      0.035    -16.515      0.000      -0.642      -0.505
# AGE775214      0.6890      0.068     10.061      0.000       0.555       0.823
# PST120214      0.4819      0.047     10.330      0.000       0.390       0.573
# RHI825214      0.2624      0.065      4.057      0.000       0.136       0.389
# LND110210      0.0002      0.000      1.786      0.074   -1.84e-05       0.000
# SEX255214      0.4990      0.120      4.166      0.000       0.264       0.734
# SBO315207     -0.2770      0.032     -8.774      0.000      -0.339      -0.215
# RHI425214      0.5541      0.074      7.479      0.000       0.409       0.699
# POP645213     -0.0292      0.046     -0.634      0.526      -0.120       0.061
# AGE135214     -0.4820      0.230     -2.100      0.036      -0.932      -0.032
# HSD310213      9.2683      1.310      7.074      0.000       6.699      11.837
# POP715213     -0.2401      0.053     -4.545      0.000      -0.344      -0.137
# RHI325214      0.3625      0.072      5.005      0.000       0.220       0.505
# LFE305213     -0.1970      0.039     -5.007      0.000      -0.274      -0.120
# RHI725214      0.2385      0.060      3.994      0.000       0.121       0.356
# HSG445213      0.0035      0.046      0.075      0.940      -0.087       0.094
# HSG096213     -0.0429      0.029     -1.487      0.137      -0.100       0.014
# POP060210     -0.0001   2.66e-05     -4.451      0.000      -0.000   -6.61e-05
# ==============================================================================
# Omnibus:                      729.698   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12780.384
# Skew:                          -0.921   Prob(JB):                         0.00
# Kurtosis:                      13.941   Cond. No.                     3.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
##modal fitting with weights = population
y='HilaryPercent'
weights='PST045214'
X=Features_fw
lmfit= sm.WLS(train[y],train[X],weights=train[weights]).fit()

lmfit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  WLS Regression Results
# =======================================================================================
# Dep. Variable:          HilaryPercent   R-squared (uncentered):                   0.986
# Model:                            WLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              7392.
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):                        0.00
# Time:                        16:14:07   Log-Likelihood:                         -9801.4
# No. Observations:                2492   AIC:                                  1.965e+04
# Df Residuals:                    2468   BIC:                                  1.979e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RHI225214      1.3321      0.077     17.304      0.000       1.181       1.483
# EDU635213     -0.5705      0.056    -10.229      0.000      -0.680      -0.461
# RHI625214     -1.3919      0.146     -9.561      0.000      -1.677      -1.106
# INC910213      0.0013   5.94e-05     21.634      0.000       0.001       0.001
# HSG495213  -1.835e-05   3.15e-06     -5.829      0.000   -2.45e-05   -1.22e-05
# SBO415207      0.3793      0.040      9.553      0.000       0.301       0.457
# EDU685213     -0.5318      0.042    -12.752      0.000      -0.614      -0.450
# AGE775214      0.5778      0.077      7.491      0.000       0.427       0.729
# PST120214      0.4394      0.054      8.072      0.000       0.333       0.546
# RHI825214      0.4291      0.075      5.699      0.000       0.281       0.577
# LND110210     -0.0001      0.000     -1.160      0.246      -0.000    8.47e-05
# SEX255214      0.8055      0.134      6.009      0.000       0.543       1.068
# SBO315207     -0.2714      0.042     -6.482      0.000      -0.354      -0.189
# RHI425214      0.9538      0.091     10.522      0.000       0.776       1.132
# POP645213     -0.1514      0.058     -2.630      0.009      -0.264      -0.039
# AGE135214     -1.8327      0.266     -6.886      0.000      -2.355      -1.311
# HSD310213      7.9165      1.460      5.421      0.000       5.053      10.780
# POP715213     -0.1852      0.062     -2.973      0.003      -0.307      -0.063
# RHI325214      0.5626      0.085      6.616      0.000       0.396       0.729
# LFE305213     -0.1843      0.047     -3.952      0.000      -0.276      -0.093
# RHI725214      0.4253      0.068      6.215      0.000       0.291       0.560
# HSG445213     -0.0228      0.054     -0.419      0.675      -0.129       0.084
# HSG096213     -0.1070      0.035     -3.091      0.002      -0.175      -0.039
# POP060210   -8.25e-05    3.7e-05     -2.228      0.026      -0.000   -9.89e-06
# ==============================================================================
# Omnibus:                      957.392   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16029.433
# Skew:                          -1.368   Prob(JB):                         0.00
# Kurtosis:                      15.120   Cond. No.                     2.84e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.84e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
## points with the biggest residuals
train['fittedvalues']=lmfit2.fittedvalues 
meaning(train.iloc[abs(lmfit2.resid_pearson).argsort()[-10:]])
# Out:
#          Population, 2014 estimate  Population, 2010 (April 1) estimates base  \
# 92 MI                       629237                                     602622
# 1147 MO                    1001876                                     998883
# 57 MI                      1764804                                    1820641
# 663 NJ                      669115                                     634277
# 1292 MO                     317419                                     319365
# 1731 IN                     934243                                     903389
# 33 AL                       660793                                     658350
# 1673 VA                     217853                                     204246
# 1741 UT                    1091742                                    1029655
# 424 PA                     1560297                                    1526006
#
#          Population, percent change - April 1, 2010 to July 1, 2014  \
# 92 MI                                                    4
# 1147 MO                                                  0
# 57 MI                                                   -3
# 663 NJ                                                   6
# 1292 MO                                                 -1
# 1731 IN                                                  3
# 33 AL                                                    0
# 1673 VA                                                  7
# 1741 UT                                                  6
# 424 PA                                                   2
#
#          Population, 2010  Persons under 5 years, percent, 2014  \
# 92 MI              602622                                     7
# 1147 MO            998954                                     6
# 57 MI             1820584                                     6
# 663 NJ             634266                                     7
# 1292 MO            319294                                     7
# 1731 IN            903393                                     8
# 33 AL              658466                                     7
# 1673 VA            204214                                     6
# 1741 UT           1029655                                     8
# 424 PA            1526006                                     7
#
#          Persons under 18 years, percent, 2014  \
# 92 MI                                       25
# 1147 MO                                     22
# 57 MI                                       24
# 663 NJ                                      20
# 1292 MO                                     20
# 1731 IN                                     25
# 33 AL                                       23
# 1673 VA                                     18
# 1741 UT                                     28
# 424 PA                                      22
#
#          Persons 65 years and over, percent, 2014  \
# 92 MI                                          12
# 1147 MO                                        16
# 57 MI                                          14
# 663 NJ                                         11
# 1292 MO                                        11
# 1731 IN                                        11
# 33 AL                                          14
# 1673 VA                                        11
# 1741 UT                                        10
# 424 PA                                         12
#
#          Female persons, percent, 2014  White alone, percent, 2014  \
# 92 MI                               51                          83
# 1147 MO                             53                          70
# 57 MI                               52                          55
# 663 NJ                              50                          66
# 1292 MO                             52                          47
# 1731 IN                             52                          66
# 33 AL                               53                          54
# 1673 VA                             52                          45
# 1741 UT                             50                          88
# 424 PA                              53                          45
#
#          Black or African American alone, percent, 2014  \
# 92 MI                                                10
# 1147 MO                                              24
# 57 MI                                                39
# 663 NJ                                               15
# 1292 MO                                              48
# 1731 IN                                              28
# 33 AL                                                43
# 1673 VA                                              50
# 1741 UT                                               2
# 424 PA                                               44
#
#          American Indian and Alaska Native alone, percent, 2014  \
# 92 MI                                                    1
# 1147 MO                                                  0
# 57 MI                                                    0
# 663 NJ                                                   1
# 1292 MO                                                  0
# 1731 IN                                                  0
# 33 AL                                                    0
# 1673 VA                                                  1
# 1741 UT                                                  1
# 424 PA                                                   1
#
#          Asian alone, percent, 2014  \
# 92 MI                             3
# 1147 MO                           4
# 57 MI                             3
# 663 NJ                           15
# 1292 MO                           3
# 1731 IN                           3
# 33 AL                             2
# 1673 VA                           2
# 1741 UT                           4
# 424 PA                            7
#
#          Native Hawaiian and Other Pacific Islander alone, percent, 2014  \
# 92 MI                                                    0
# 1147 MO                                                  0
# 57 MI                                                    0
# 663 NJ                                                   0
# 1292 MO                                                  0
# 1731 IN                                                  0
# 33 AL                                                    0
# 1673 VA                                                  0
# 1741 UT                                                  2
# 424 PA                                                   0
#
#          Two or More Races, percent, 2014  Hispanic or Latino, percent, 2014  \
# 92 MI                                   3                                 10
# 1147 MO                                 2                                  3
# 57 MI                                   2                                  6
# 663 NJ                                  3                                 43
# 1292 MO                                 2                                  4
# 1731 IN                                 3                                 10
# 33 AL                                   1                                  4
# 1673 VA                                 2                                  7
# 1741 UT                                 3                                 18
# 424 PA                                  2                                 14
#
#          White alone, not Hispanic or Latino, percent, 2014  \
# 92 MI                                                   75
# 1147 MO                                                 68
# 57 MI                                                   50
# 663 NJ                                                  29
# 1292 MO                                                 44
# 1731 IN                                                 58
# 33 AL                                                   51
# 1673 VA                                                 40
# 1741 UT                                                 73
# 424 PA                                                  36
#
#          Living in same house 1 year & over, percent, 2009-2013  \
# 92 MI                                                   84
# 1147 MO                                                 86
# 57 MI                                                   86
# 663 NJ                                                  86
# 1292 MO                                                 78
# 1731 IN                                                 82
# 33 AL                                                   84
# 1673 VA                                                 77
# 1741 UT                                                 83
# 424 PA                                                  86
#
#          Foreign born persons, percent, 2009-2013  \
# 92 MI                                           7
# 1147 MO                                         7
# 57 MI                                           8
# 663 NJ                                         41
# 1292 MO                                         7
# 1731 IN                                         8
# 33 AL                                           4
# 1673 VA                                         7
# 1741 UT                                        12
# 424 PA                                         12
#
#          Language other than English spoken at home, pct age 5+, 2009-2013  \
# 92 MI                                                   11
# 1147 MO                                                  9
# 57 MI                                                   13
# 663 NJ                                                  59
# 1292 MO                                                 10
# 1731 IN                                                 12
# 33 AL                                                    6
# 1673 VA                                                 10
# 1741 UT                                                 20
# 424 PA                                                  22
#
#          High school graduate or higher, percent of persons age 25+, 2009-2013  \
# 92 MI                                                   89
# 1147 MO                                                 92
# 57 MI                                                   84
# 663 NJ                                                  82
# 1292 MO                                                 83
# 1731 IN                                                 84
# 33 AL                                                   87
# 1673 VA                                                 82
# 1741 UT                                                 89
# 424 PA                                                  81
#
#          Bachelor's degree or higher, percent of persons age 25+, 2009-2013  \
# 92 MI                                                   32
# 1147 MO                                                 41
# 57 MI                                                   21
# 663 NJ                                                  36
# 1292 MO                                                 30
# 1731 IN                                                 27
# 33 AL                                                   30
# 1673 VA                                                 35
# 1741 UT                                                 31
# 424 PA                                                  24
#
#          Veterans, 2009-2013  \
# 92 MI                  34393
# 1147 MO                70308
# 57 MI                 105562
# 663 NJ                 16139
# 1292 MO                19347
# 1731 IN                57036
# 33 AL                  46613
# 1673 VA                12126
# 1741 UT                49590
# 424 PA                 74487
#
#          Mean travel time to work (minutes), workers age 16+, 2009-2013  \
# 92 MI                                                   21
# 1147 MO                                                 23
# 57 MI                                                   25
# 663 NJ                                                  34
# 1292 MO                                                 24
# 1731 IN                                                 23
# 33 AL                                                   23
# 1673 VA                                                 22
# 1741 UT                                                 22
# 424 PA                                                  32
#
#          Housing units, 2014  Homeownership rate, 2009-2013  \
# 92 MI                 248724                             70
# 1147 MO               438081                             71
# 57 MI                 814399                             65
# 663 NJ                277166                             33
# 1292 MO               175355                             45
# 1731 IN               419350                             56
# 33 AL                 305040                             65
# 1673 VA               100107                             43
# 1741 UT               376456                             67
# 424 PA                670401                             53
#
#          Housing units in multi-unit structures, percent, 2009-2013  \
# 92 MI                                                   24
# 1147 MO                                                 23
# 57 MI                                                   23
# 663 NJ                                                  84
# 1292 MO                                                 53
# 1731 IN                                                 31
# 33 AL                                                   24
# 1673 VA                                                 43
# 1741 UT                                                 28
# 424 PA                                                  33
#
#          Median value of owner-occupied housing units, 2009-2013  \
# 92 MI                                               137500
# 1147 MO                                             174500
# 57 MI                                                86800
# 663 NJ                                              347200
# 1292 MO                                             119200
# 1731 IN                                             118000
# 33 AL                                               140800
# 1673 VA                                             196400
# 1741 UT                                             232100
# 424 PA                                              142500
#
#          Households, 2009-2013  Persons per household, 2009-2013  \
# 92 MI                   229373                                 3
# 1147 MO                 403293                                 2
# 57 MI                   670987                                 3
# 663 NJ                  243875                                 3
# 1292 MO                 140652                                 2
# 1731 IN                 360072                                 2
# 33 AL                   259634                                 2
# 1673 VA                  84833                                 2
# 1741 UT                 344089                                 3
# 424 PA                  580017                                 3
#
#          Per capita money income in past 12 months (2013 dollars), 2009-2013  \
# 92 MI                                                25889
# 1147 MO                                              34795
# 57 MI                                                22308
# 663 NJ                                               32641
# 1292 MO                                              23048
# 1731 IN                                              24124
# 33 AL                                                26906
# 1673 VA                                              27184
# 1741 UT                                              26103
# 424 PA                                               22279
#
#          Median household income, 2009-2013  \
# 92 MI                                 51667
# 1147 MO                               58910
# 57 MI                                 41184
# 663 NJ                                58442
# 1292 MO                               34582
# 1731 IN                               42334
# 33 AL                                 45429
# 1673 VA                               40496
# 1741 UT                               60555
# 424 PA                                37192
#
#          Persons below poverty level, percent, 2009-2013  \
# 92 MI                                                 16
# 1147 MO                                               11
# 57 MI                                                 24
# 663 NJ                                                17
# 1292 MO                                               27
# 1731 IN                                               20
# 33 AL                                                 18
# 1673 VA                                               26
# 1741 UT                                               13
# 424 PA                                                26
#
#          Private nonfarm establishments, 2013  \
# 92 MI                                   15615
# 1147 MO                                 30847
# 57 MI                                   31821
# 663 NJ                                  12879
# 1292 MO                                  9794
# 1731 IN                                 22741
# 33 AL                                   16232
# 1673 VA                                  6000
# 1741 UT                                 29886
# 424 PA                                  27239
#
#          Private nonfarm employment,  2013  \
# 92 MI                               323594
# 1147 MO                             559606
# 57 MI                               590972
# 663 NJ                              211322
# 1292 MO                             223481
# 1731 IN                             508703
# 33 AL                               319199
# 1673 VA                             122120
# 1741 UT                             524284
# 424 PA                              582474
#
#          Private nonfarm employment, percent change, 2012-2013  \
# 92 MI                                                    1
# 1147 MO                                                  2
# 57 MI                                                    2
# 663 NJ                                                   0
# 1292 MO                                                 -1
# 1731 IN                                                  2
# 33 AL                                                    2
# 1673 VA                                                  8
# 1741 UT                                                  2
# 424 PA                                                  -2
#
#          Nonemployer establishments, 2013  Total number of firms, 2007  \
# 92 MI                               43713                        52369
# 1147 MO                             72436                        91810
# 57 MI                              126314                       137728
# 663 NJ                              48782                        55520
# 1292 MO                             21248                        23632
# 1731 IN                             58749                        69266
# 33 AL                               44987                        55470
# 1673 VA                             13688                        15141
# 1741 UT                             76464                        97576
# 424 PA                              80370                        88140
#
#          Black-owned firms, percent, 2007  \
# 92 MI                                   6
# 1147 MO                                10
# 57 MI                                  29
# 663 NJ                                 12
# 1292 MO                                21
# 1731 IN                                12
# 33 AL                                  23
# 1673 VA                                21
# 1741 UT                                 1
# 424 PA                                 22
#
#          American Indian- and Alaska Native-owned firms, percent, 2007  \
# 92 MI                                                    1
# 1147 MO                                                  0
# 57 MI                                                    1
# 663 NJ                                                   0
# 1292 MO                                                  1
# 1731 IN                                                  1
# 33 AL                                                    0
# 1673 VA                                                  0
# 1741 UT                                                  1
# 424 PA                                                   1
#
#          Asian-owned firms, percent, 2007  \
# 92 MI                                   3
# 1147 MO                                 4
# 57 MI                                   4
# 663 NJ                                 13
# 1292 MO                                 5
# 1731 IN                                 2
# 33 AL                                   2
# 1673 VA                                 4
# 1741 UT                                 3
# 424 PA                                 10
#
#          Native Hawaiian- and Other Pacific Islander-owned firms, percent, 2007  \
# 92 MI                                                    0
# 1147 MO                                                  0
# 57 MI                                                    0
# 663 NJ                                                   0
# 1292 MO                                                  0
# 1731 IN                                                  0
# 33 AL                                                    0
# 1673 VA                                                  0
# 1741 UT                                                  0
# 424 PA                                                   0
#
#          Hispanic-owned firms, percent, 2007  \
# 92 MI                                      2
# 1147 MO                                    1
# 57 MI                                      2
# 663 NJ                                    26
# 1292 MO                                    1
# 1731 IN                                    2
# 33 AL                                      1
# 1673 VA                                    1
# 1741 UT                                    5
# 424 PA                                     8
#
#          Women-owned firms, percent, 2007  \
# 92 MI                                  30
# 1147 MO                                27
# 57 MI                                  37
# 663 NJ                                 28
# 1292 MO                                28
# 1731 IN                                28
# 33 AL                                  30
# 1673 VA                                29
# 1741 UT                                26
# 424 PA                                 32
#
#          Manufacturers shipments, 2007 ($1,000)  \
# 92 MI                                  15738279
# 1147 MO                                22654565
# 57 MI                                  55896948
# 663 NJ                                  2614244
# 1292 MO                                10920629
# 1731 IN                                24333886
# 33 AL                                  10260950
# 1673 VA                                10192124
# 1741 UT                                18860476
# 424 PA                                 18069415
#
#          Merchant wholesaler sales, 2007 ($1,000)  \
# 92 MI                                    13020792
# 1147 MO                                  27366632
# 57 MI                                    26102859
# 663 NJ                                   14524927
# 1292 MO                                   5042147
# 1731 IN                                  15780255
# 33 AL                                    13756797
# 1673 VA                                   2843348
# 1741 UT                                  16956359
# 424 PA                                   11566105
#
#          Retail sales, 2007 ($1,000)  Retail sales per capita, 2007  \
# 92 MI                        8058005                          13377
# 1147 MO                     17237496                          17347
# 57 MI                       17275751                           8720
# 663 NJ                       6099871                          10350
# 1292 MO                      2496672                           7020
# 1731 IN                     12951290                          14748
# 33 AL                       11066328                          16730
# 1673 VA                      1922799                           9583
# 1741 UT                     16758729                          16718
# 424 PA                      11167787                           7299
#
#          Accommodation and food services sales, 2007 ($1,000)  \
# 92 MI                                               925177
# 1147 MO                                            2440721
# 57 MI                                              3112369
# 663 NJ                                              880714
# 1292 MO                                            1059295
# 1731 IN                                            2248380
# 33 AL                                              1268154
# 1673 VA                                             476810
# 1741 UT                                            1874594
# 424 PA                                             3051401
#
#          Building permits, 2014  Land area in square miles, 2010  \
# 92 MI                      1711                              847
# 1147 MO                    1062                              508
# 57 MI                      1001                              612
# 663 NJ                     4621                               46
# 1292 MO                     758                               62
# 1731 IN                    1195                              396
# 33 AL                      2280                            1,111
# 1673 VA                     551                               60
# 1741 UT                    4943                              742
# 424 PA                     3973                              134
#
#          Population per square mile, 2010  HilaryPercent       n  fittedvalues
# 92 MI                                 712             37   69274            46
# 1147 MO                             1,967             56  160507            62
# 57 MI                               2,974             61  268885            66
# 663 NJ                             13,731             66   74910            58
# 1292 MO                             5,158             55   62206            66
# 1731 IN                             2,280             50  118448            59
# 33 AL                                 592             82   81676            72
# 1673 VA                             3,415             61   35907            77
# 1741 UT                             1,387             21   45041            43
# 424 PA                             11,380             63  338473            72

# %%
#We will opt for the 2nd one 
lmfit2.predict(test[Features_fw]).describe()
# Out:
# count   300
# mean     56
# std      12
# min      27
# 25%      48
# 50%      52
# 75%      62
# max     102
# dtype: float64

# %%
def sup(x):
    '''Results are in percentage => points superior to 100 are rounded to 100 '''
    if x>100:
        return 100
    else:
        return x
    
results=lmfit2.predict(test[Features_fw]).apply(sup)

# %%
results.to_csv('Step2.csv',index=False)
